# %% [markdown]
# # 現代程式語言 期中專案 - 家樂福衛生紙價格比較
# 第八組 111210518 陳辰鈺、111210520 吳佳泰、111210524藍健洲
# date:10/28

# %% [markdown]
# ## Step3.從資料庫提取資料

# %%
import sqlite3
import pandas
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']  
plt.rcParams['axes.unicode_minus'] = False 

with sqlite3.connect ("tissue.db") as con:
    c = con.cursor()
    tissue = pandas.read_sql("SELECT * FROM tissue" , con=con)


    list1 = list(tissue.name)
    list2 = list(tissue.price)

    print(list1)
    print(list2)
# Out:
# ['春風抽取式衛生紙優質經濟包-100PC', '家樂福3層抽取式衛生紙', '五月花厚棒抽取式衛生紙FSC 90*10', '[箱購]得意優質抽取式衛生紙100PCx24包x3袋', '舒潔三層竹炭萃取抽取衛生紙94PCx20*迪士尼限量包裝,恕不指定(以實際出貨為主)', '家樂福超值連續抽取式花紋衛生紙輕巧包', '家樂福抽取式衛生紙-FSC 110X36', '[箱購]唯潔雅抽取式衛生紙100PC24包x4袋', '唯潔雅輕巧萬用抽取式衛生紙120PC', '唯潔雅抽取式衛生紙100PCx24', '得意3層連續抽取式花紋衛生紙', '五月花舒敏厚棒抽取式衛生紙86PC', '蒲公英環保抽取衛生紙100PCx12', '家樂福抽取式衛生紙FSC24入', '家樂福抽取式花紋衛生紙(FSC)130PCx12', '春風山茶花精華抽取式衛生紙-100PC', '[箱購]舒潔三層竹炭萃取抽取衛生紙 FSC 94抽20包X4袋*迪士尼限量包裝,恕不指定(以實際出貨為主)', '舒潔迪士尼抽取衛生紙超值包FSC', '家樂福抽取式衛生紙FSC72入', '倍潔雅抽取式衛生紙', '得意優質抽取式衛生紙100PCx24', '舒潔抽取式廚房紙巾 FSC 110抽', 'Gentto上質柔三層抽取式衛生紙FSC', '舒潔絲柔乳液抽取衛生紙超值包-100PCx30包']
# [88, 308, 199, 663, 395, 185, 365, 860, 309, 215, 596, 199, 125, 249, 175, 299, 1580, 315, 747, 215, 239, 109, 159, 499]

# %% [markdown]
# ## Step4.使用提取出的資料繪圖

# %% [markdown]
# ### (1)折線圖 plot

# %%
plt.plot(list1 , list2)
plt.title("家樂福衛生紙價格比較")
plt.xlabel("品牌")
plt.ylabel("價格(元)")
# Out:
# Text(0, 0.5, '價格(元)')

# %% [markdown]
# ### (2)長條圖 bar

# %%
plt.bar(list1 , list2)
plt.title("家樂福衛生紙價格比較")
plt.xlabel("品牌")
plt.ylabel("價格(元)")
# Out:
# Text(0, 0.5, '價格(元)')

# %% [markdown]
# ### (3)橫條圖

# %%
plt.barh(list1 , list2)
plt.title("家樂福衛生紙價格比較")
plt.xlabel("品牌")
plt.ylabel("價格(元)")
# Out:
# Text(0, 0.5, '價格(元)')
